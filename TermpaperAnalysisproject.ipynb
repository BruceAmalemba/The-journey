# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pyp
import statistics

# %% [markdown]
# # importing the dataset

# %%
Term_data=pd.read_csv("C://Users//Bachelor_001//OneDrive//Desktop//PD//Termpaper.csv")

# %% [markdown]
# # DATA CLEANING

# %%
Term_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   X                       1000 non-null   float64
#  1   Sex                     1000 non-null   float64
#  2   Marital Status          1000 non-null   object
#  3   Age                     1000 non-null   float64
#  4   Occupation              1000 non-null   float64
#  5   Education (Years)       1000 non-null   object
#  6   Distance (Miles)        1000 non-null   object
#  7   Years Current Employer  1000 non-null   float64
#  8   Annual Income ('000)    1000 non-null   float64
#  9   Residence Size          1000 non-null   float64
#  10  Family Size             1000 non-null   float64
# dtypes: float64(8), object(3)
# memory usage: 86.2+ KB

# %% [markdown]
#  python automatically removes the NA

# %%
Term_data.keys()
# Out:
# Index(['X', 'Sex', 'Marital Status', 'Age', 'Occupation', 'Education (Years)',
#        'Distance (Miles)', 'Years Current Employer', 'Annual Income ('000)',
#        'Residence Size', 'Family Size'],
#       dtype='object')

# %%
Term_data.sample(10)
# Out:
#          X  Sex Marital Status   Age  Occupation Education (Years)  \
# 904  905.0  1.0              1  51.0         3.0                14
# 188  189.0  1.0              2  53.0         4.0                16
# 451  452.0  2.0              3  24.0         4.0                14
# 515  516.0  1.0              2  42.0         4.0                12
# 165  166.0  1.0              1  47.0         2.0                16
# 461  462.0  1.0              2  35.0         5.0                12
# 624  625.0  2.0              1  38.0         3.0                12
# 635  636.0  1.0              3  18.0         3.0                12
# 123  124.0  1.0              2  31.0         1.0                16
# 706  707.0  1.0              1  38.0         5.0                12
#
#     Distance (Miles)  Years Current Employer  Annual Income ('000)  \
# 904                9                    20.0                  24.0
# 188               23                    20.0                  21.0
# ...

# %% [markdown]
# # inspecting sex

# %%
Term_data['Sex']=Term_data['Sex'].astype('category')

# %%
Term_data['Sex'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1001 entries, 0 to 1000
# Series name: Sex
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   category
# dtypes: category(1)
# memory usage: 1.2 KB

# %%
Term_data['Sex'].unique()
# Out:
# [1.0, 2.0, NaN]
# Categories (2, float64): [1.0, 2.0]

# %% [markdown]
# # checking my data info

# %% [markdown]
# # checking for missing values

# %%
Term_data[Term_data['X'].isna()]
# Out:
#        X Sex Marital Status  Age  Occupation Education (Years)  \
# 1000 NaN NaN            NaN  NaN         NaN               NaN
#
#      Distance (Miles)  Years Current Employer  Annual Income ('000)  \
# 1000              NaN                     NaN                   NaN
#
#       Residence Size  Family Size
# 1000             NaN          NaN

# %% [markdown]
# # dropping the 1000 row

# %%
Term_data=Term_data.dropna(how='all')

# %%
Term_data['Marital Status'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1000 entries, 0 to 999
# Series name: Marital Status
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   object
# dtypes: object(1)
# memory usage: 15.6+ KB

# %%
Term_data['Marital Status'].unique()
# Out:
# array(['2', '1', '3', '3_', 'I'], dtype=object)

# %%
Term_data[Term_data['Marital Status']=='I']
# Out:
#          X  Sex Marital Status   Age  Occupation Education (Years)  \
# 885  886.0  2.0              I  24.0         1.0                16
#
#     Distance (Miles)  Years Current Employer  Annual Income ('000)  \
# 885               15                     1.0                  19.0
#
#      Residence Size  Family Size
# 885            11.0          1.0

# %%
#Term_data[Term_data['Marital Status']=='3_']
#Term_data
Term_data['Marital Status']=Term_data['Marital Status'].replace({'I':'1','3_':'3'})
Term_data['Marital Status'].unique()
Term_data['Marital Status']=Term_data['Marital Status'].astype('category')
Term_data.info()
Term_data['Marital Status'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   X                       1000 non-null   float64
#  1   Sex                     1000 non-null   category
#  2   Marital Status          1000 non-null   category
#  3   Age                     1000 non-null   float64
#  4   Occupation              1000 non-null   float64
#  5   Education (Years)       1000 non-null   object
#  6   Distance (Miles)        1000 non-null   object
#  7   Years Current Employer  1000 non-null   float64
#  8   Annual Income ('000)    1000 non-null   float64
#  9   Residence Size          1000 non-null   float64
#  10  Family Size             1000 non-null   float64
# dtypes: category(2), float64(7), object(2)
# memory usage: 80.3+ KB
# ['2', '1', '3']
# Categories (3, object): ['1', '2', '3']

# %%
Term_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   X                       1000 non-null   float64
#  1   Sex                     1000 non-null   category
#  2   Marital Status          1000 non-null   category
#  3   Age                     1000 non-null   float64
#  4   Occupation              1000 non-null   float64
#  5   Education (Years)       1000 non-null   object
#  6   Distance (Miles)        1000 non-null   object
#  7   Years Current Employer  1000 non-null   float64
#  8   Annual Income ('000)    1000 non-null   float64
#  9   Residence Size          1000 non-null   float64
#  10  Family Size             1000 non-null   float64
# dtypes: category(2), float64(7), object(2)
# memory usage: 80.3+ KB

# %%
Term_data=Term_data.drop('X',axis='columns')
pd.set_option('display.max_rows',None)
Term_data
# Out:
#      Sex Marital Status   Age  Occupation Education (Years) Distance (Miles)  \
# 0    1.0              2  29.0         4.0                14               12
# 1    1.0              2  48.0         1.0                16               34
# 2    1.0              2  41.0         5.0                12               12
# 3    1.0              2  54.0         4.0                14               18
# 4    1.0              2  44.0         4.0                12                5
# 5    1.0              2  57.0         3.0                16               30
# 6    1.0              1  45.0         2.0                16               22
# 7    1.0              2  59.0         2.0                12               20
# 8    1.0              1  18.0         3.0                12               17
# 9    1.0              2  49.0         3.0                14               24
# 10   1.0              2  43.0         2.0                16                7
# ...

# %%
Term_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sex                     1000 non-null   category
#  1   Marital Status          1000 non-null   category
#  2   Age                     1000 non-null   float64
#  3   Occupation              1000 non-null   float64
#  4   Education (Years)       1000 non-null   object
#  5   Distance (Miles)        1000 non-null   object
#  6   Years Current Employer  1000 non-null   float64
#  7   Annual Income ('000)    1000 non-null   float64
#  8   Residence Size          1000 non-null   float64
#  9   Family Size             1000 non-null   float64
# dtypes: category(2), float64(6), object(2)
# memory usage: 72.5+ KB

# %%
pd.set_option('display.max_rows',None)

# %%
Term_data['Occupation']=Term_data['Occupation'].astype('category')
Term_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sex                     1000 non-null   category
#  1   Marital Status          1000 non-null   category
#  2   Age                     1000 non-null   float64
#  3   Occupation              1000 non-null   category
#  4   Education (Years)       1000 non-null   object
#  5   Distance (Miles)        1000 non-null   object
#  6   Years Current Employer  1000 non-null   float64
#  7   Annual Income ('000)    1000 non-null   float64
#  8   Residence Size          1000 non-null   float64
#  9   Family Size             1000 non-null   float64
# dtypes: category(3), float64(5), object(2)
# memory usage: 65.9+ KB

# %% [markdown]
# # EDUCATION

# %%
Term_data['Education (Years)'].unique()
Term_data['Education (Years)']=Term_data['Education (Years)'].replace({'..16':'16','16 .':'16'})
Term_data['Education (Years)'].unique()
Term_data['Education (Years)']=Term_data['Education (Years)'].astype('int')
Term_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sex                     1000 non-null   category
#  1   Marital Status          1000 non-null   category
#  2   Age                     1000 non-null   float64
#  3   Occupation              1000 non-null   category
#  4   Education (Years)       1000 non-null   int32
#  5   Distance (Miles)        1000 non-null   object
#  6   Years Current Employer  1000 non-null   float64
#  7   Annual Income ('000)    1000 non-null   float64
#  8   Residence Size          1000 non-null   float64
#  9   Family Size             1000 non-null   float64
# dtypes: category(3), float64(5), int32(1), object(1)
# memory usage: 62.0+ KB

# %% [markdown]
# # DISTANCE

# %%
Term_data['Distance (Miles)'].unique   
Term_data['Distance (Miles)']=Term_data['Distance (Miles)'].replace(['. 18',"'24 ",'. 10','. 8', ',11'],['18','24','10','8','11'])
Term_data['Distance (Miles)'].unique()
Term_data['Distance (Miles)']=Term_data['Distance (Miles)'].astype('int')
Term_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sex                     1000 non-null   category
#  1   Marital Status          1000 non-null   category
#  2   Age                     1000 non-null   float64
#  3   Occupation              1000 non-null   category
#  4   Education (Years)       1000 non-null   int32
#  5   Distance (Miles)        1000 non-null   int32
#  6   Years Current Employer  1000 non-null   float64
#  7   Annual Income ('000)    1000 non-null   float64
#  8   Residence Size          1000 non-null   float64
#  9   Family Size             1000 non-null   float64
# dtypes: category(3), float64(5), int32(2)
# memory usage: 58.1 KB

# %% [markdown]
# # Annual Income(000)

# %%
Term_data["Annual Income ('000)"].unique()
Term_data["Annual Income ('000)"]=Term_data["Annual Income ('000)"]*1000
Term_data["Annual Income ('000)"].unique()
Term_data["Annual Income ('000)"]=Term_data["Annual Income ('000)"].astype('int')

# %% [markdown]
# # Residence Size

# %%
Term_data['Residence Size'].unique()
Term_data['Residence Size']=Term_data['Residence Size'].astype('int')

# %% [markdown]
# # Family Size

# %%
Term_data['Family Size'].unique
Term_data[Term_data["Family Size"]=='1']
Term_data['Family Size']=Term_data['Family Size'].astype('category')
Term_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sex                     1000 non-null   category
#  1   Marital Status          1000 non-null   category
#  2   Age                     1000 non-null   float64
#  3   Occupation              1000 non-null   category
#  4   Education (Years)       1000 non-null   int32
#  5   Distance (Miles)        1000 non-null   int32
#  6   Years Current Employer  1000 non-null   float64
#  7   Annual Income ('000)    1000 non-null   int32
#  8   Residence Size          1000 non-null   int32
#  9   Family Size             1000 non-null   category
# dtypes: category(4), float64(2), int32(4)
# memory usage: 43.6 KB

# %% [markdown]
# # DATA EXPLORATION
#                    -Plotiing
#                    -Distribution
#                    -observe outliers

# %% [markdown]
# # notes to keep
#                 -fillna >when the didtribution (mean) is symmetric
#                 -Normalize > when skew
#                 -mode() >when object/categorical variable

# %% [markdown]
# # Exploring Age

# %%
import matplotlib
dir(matplotlib.pyplot)
from matplotlib.pyplot import boxplot
pyp.boxplot(Term_data['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e12a6d0140>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e12a6d0740>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e12a63fe90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e12a6d0ce0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e12a6d0fe0>],
#  'means': []}

# %% [markdown]
# # yellow line --> median

# %%
Term_data.boxplot(column ="Age")
# Out:
# <Axes: >

# %% [markdown]
# # Exploring education years

# %%
Term_data['Education (Years)'].info()
Term_data.boxplot(column ='Education (Years)')
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1000 entries, 0 to 999
# Series name: Education (Years)
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   int32
# dtypes: int32(1)
# memory usage: 11.7 KB
# <Axes: >

# %% [markdown]
# # has no outliers   ie its symmetric (the midian is in the middle)

# %%
Term_data.boxplot(column='Distance (Miles)')
# Out:
# <Axes: >

# %% [markdown]
# # EXPLORING ANNUAL INCOME

# %%
Term_data.boxplot(column ="Annual Income ('000)")
# Out:
# <Axes: >

# %% [markdown]
# annual income has 4 outliers

# %% [markdown]
# # EXPLORING RESIDENCE

# %%
Term_data.boxplot(column ='Residence Size')
# Out:
# <Axes: >

# %% [markdown]
# Residence Size  has one outlier

# %%
dir(matplotlib.pyplot)
Term_data.hist(column ='Age')
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
Term_data['Age'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# bins reduces the density of the bars

# %% [markdown]
# # Distribution for Education

# %%
Term_data['Education (Years)'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# education is symmetric

# %% [markdown]
# # Distribution for distance

# %%
Term_data['Distance (Miles)'].hist(bins=200)
# Out:
# <Axes: >

# %% [markdown]
# distance is skewed

# %%
Term_data['Residence Size'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# distance is skewed

# %%
Term_data["Annual Income ('000)"].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# ### NORMALIZING

# %%
Term_data['Normalized_annual_income']=np.log(Term_data["Annual Income ('000)"])

# %%
Term_data.boxplot(column ='Normalized_annual_income')
# Out:
# <Axes: >

# %%
# Term_data['Normalized_annual_income']=Term_data['Normalized_annual_income']*1000
# Term_data.sample(5)
def apply(n):
    return(n*1000)
Term_data['Normalized_annual_income']=apply(Term_data['Normalized_annual_income'])

# %% [markdown]
# ### DESCRIPTIVE ANALYSIS
#     - This is the analysis that focuses majorly  on numericxcal vcariablke
#     -we talk of stuffs like; mean,starndard deviation,quartiles,maximum abd minimum

# %% [markdown]
# when comparing two mean use Z-test/t-test depending on the variance ie if variance is known  use Z

# %% [markdown]
# when comparing variance use  chi square

# %% [markdown]
# #### The best visualisation for:
#        i.mean analysis--combined line gragh
#        ii.Outliers -- boxplot
#        iii.distribution---histograms(hist)

# %%
Term_data.describe()
# Out:
#                Age  Education (Years)  Distance (Miles)  \
# count  1000.000000        1000.000000       1000.000000
# mean     35.994000          14.297000         18.957000
# std      11.144333           1.965873          9.031319
# min      18.000000          12.000000          1.000000
# 25%      27.000000          12.000000         11.000000
# 50%      35.000000          14.000000         18.000000
# 75%      44.000000          16.000000         26.000000
# max      60.000000          18.000000         35.000000
#
#        Years Current Employer  Annual Income ('000)  Residence Size  \
# count             1000.000000           1000.000000     1000.000000
# mean                10.188000          24150.000000       17.907000
# std                  8.058511          10185.442712       10.358941
# min                  1.000000          10000.000000        4.000000
# 25%                  3.000000          16000.000000        7.000000
# ...

# %%
descriptive_analysis=Term_data.describe()
descriptive_analysis=pd.DataFrame(descriptive_analysis)
descriptive_analysis
# Out:
#                Age  Education (Years)  Distance (Miles)  \
# count  1000.000000        1000.000000       1000.000000
# mean     35.994000          14.297000         18.957000
# std      11.144333           1.965873          9.031319
# min      18.000000          12.000000          1.000000
# 25%      27.000000          12.000000         11.000000
# 50%      35.000000          14.000000         18.000000
# 75%      44.000000          16.000000         26.000000
# max      60.000000          18.000000         35.000000
#
#        Years Current Employer  Annual Income ('000)  Residence Size  \
# count             1000.000000           1000.000000     1000.000000
# mean                10.188000          24150.000000       17.907000
# std                  8.058511          10185.442712       10.358941
# min                  1.000000          10000.000000        4.000000
# 25%                  3.000000          16000.000000        7.000000
# ...

# %% [markdown]
# ## Mean analysis

# %% [markdown]
# ### Visualization

# %%
 dir(pyp.figure)
#pyp.figure(figsize=(15,8))
pyp.grid()
# pyp.plot(statistics.mean(descriptive_analysis['Age']))
# descriptive_analysis['A
descriptive_analysis['Education (Years)'].plot()
descriptive_analysis['Distance (Miles)'].plot()
descriptive_analysis['Years Current Employer'].plot()
descriptive_analysis["Annual Income ('000)"].plot()
descriptive_analysis['Residence Size'].plot()
descriptive_analysis['Normalized_annual_income'].plot()
descriptive_analysis['Age'].plot()
pyp.legend()
pyp.title('Descriptive Analysis line gragh for Term_data')
pyp.xlabel('Annual income')
pyp.ylabel('Normalized_Annual income')
pyp.savefig(' first_Descriptive_Analysis_line_gragh_for_Term_data.png')

# %% [markdown]
# Comparative analysis line graph between the normalized

# %%
descriptive_analysis["Annual Income ('000)"].plot()
descriptive_analysis['Normalized_annual_income'].plot()
pyp.legend()
pyp.title('Descriptive Analysis line gragh for Term_data')
pyp.xlabel('Annual income')
pyp.ylabel('Normalized_Annual income')
pyp.savefig('Descriptive_Analysis_line_gragh_for_Term_data.png')
